# %% [markdown]
# # Example notebook fixture
# Demonstrates repro-check's notebook conversion + out-of-order caveat.

# %%
import math
r = 2
area = math.pi * r**2

# %%
print('area of circle r=2:', round(area, 3))
